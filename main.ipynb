# %%
import plotly.express as px
import pandas as pd

# %%
data = pd.read_csv('./data.csv')
data = data[(data['target'] != 44800) & (data['target'] != 44706)]

# %%
fig = px.scatter(data, x='roads_cnt', y='amenity_cnt', color='target')
fig.show()

# %%
fig = px.scatter(data, x='stops_cnt', y='amenity_cnt', color='target')
fig.show()

# %%
fig = px.scatter(data, x='roads_cnt', y='stops_cnt', color='target')
fig.show()

# %%
fig = px.scatter(data, x='Банки', y='Супермаркеты', color='target')
fig.show()

# %%
fig = px.scatter(data, x='Кафе', y='Быстрое питание', color='target')
fig.show()
